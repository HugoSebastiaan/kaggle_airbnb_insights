# %% [markdown]
# # Airbnb Prices in European Cities
#
# https://www.kaggle.com/datasets/thedevastator/airbnb-prices-in-european-cities

# %% [markdown]
# ## Schema
#
# Column name	Description
# - realSum	The total price of the Airbnb listing. (Numeric)
# - room_type	The type of room being offered (e.g. private, shared, etc.). (Categorical)
# - room_shared	Whether the room is shared or not. (Boolean)
# - room_private	Whether the room is private or not. (Boolean)
# - person_capacity	The maximum number of people that can stay in the room. (Numeric)
# - host_is_superhost	Whether the host is a superhost or not. (Boolean)
# - multi	Whether the listing is for multiple rooms or not. (Boolean)
# - biz	Whether the listing is for business purposes or not. (Boolean)
# - cleanliness_rating	The cleanliness rating of the listing. (Numeric)
# - guest_satisfaction_overall	The overall guest satisfaction rating of the listing. (Numeric)
# - bedrooms	The number of bedrooms in the listing. (Numeric)
# - dist	The distance from the city centre. (Numeric)
# - metro_dist	The distance from the nearest metro station. (Numeric)
# - lng	The longitude of the listing. (Numeric)
# - lat	The latitude of the listing. (Numeric)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Directory path
cwd = os.getcwd()
#directory = "aex_data/"
print(type(cwd))
datasets_directory ="\\".join(cwd.split("\\")[:-1])
# List files and directories in the directory
print(datasets_directory)
files_and_directories = os.listdir(cwd)
dataset = os.listdir(datasets_directory)
# Print the list
print("Files and directories in", cwd, ":")
for item in files_and_directories:
    print(item)

print("Files and directories in", datasets_directory, ":")
for item in dataset:
    print(item)
# Out:
# <class 'str'>
# C:\Users\Asus\Desktop\PersonalProject\Kaggle\AirBnB
# Files and directories in C:\Users\Asus\Desktop\PersonalProject\Kaggle\AirBnB\kaggle_airbnb_insights :
# .git
# .ipynb_checkpoints
# Kaggle_airbnb_insights.ipynb
# README.md
# Files and directories in C:\Users\Asus\Desktop\PersonalProject\Kaggle\AirBnB :
# amsterdam_weekdays.csv
# amsterdam_weekends.csv
# athens_weekdays.csv
# athens_weekends.csv
# barcelona_weekdays.csv
# barcelona_weekends.csv
# berlin_weekdays.csv
# berlin_weekends.csv
# budapest_weekdays.csv
# budapest_weekends.csv
# kaggle_airbnb_insights
# lisbon_weekdays.csv
# lisbon_weekends.csv
# london_weekdays.csv
# london_weekends.csv
# paris_weekdays.csv
# paris_weekends.csv
# rome_weekdays.csv
# rome_weekends.csv
# vienna_weekdays.csv
# vienna_weekends.csv

# %%
designated_stock_path = datasets_directory +"\\" +"amsterdam_weekdays.csv"
df_AMS_weekdays = pd.read_csv(designated_stock_path)

# %%
df_AMS_weekdays.head()
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0              2.0              False      1    0                10.0
# 1              4.0              False      0    0                 8.0
# 2              2.0              False      0    1                 9.0
# 3              4.0              False      0    1                 9.0
# 4              2.0               True      0    0                10.0
#
#    guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# ...

# %%
# Remove index column
df_AMS_weekdays_drop1 = df_AMS_weekdays.drop(columns=["Unnamed: 0"])

# %%
df_AMS_weekdays_drop1.tail()
# Out:
#           realSum        room_type  room_shared  room_private  \
# 1098  2486.115342  Entire home/apt        False         False
# 1099   233.637194     Private room        False          True
# 1100   317.062311     Private room        False          True
# 1101  1812.855904  Entire home/apt        False         False
# 1102   258.008577      Shared room         True         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 1098              2.0              False      0    0                10.0
# 1099              2.0              False      1    0                10.0
# 1100              2.0              False      1    0                10.0
# 1101              4.0              False      0    0                 8.0
# 1102              2.0              False      0    0                 8.0
#
#       guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# ...

# %%
df_AMS_weekdays_drop1.describe()
# Out:
#            realSum  person_capacity       multi          biz  \
# count  1103.000000      1103.000000  1103.00000  1103.000000
# mean    545.020526         2.792384     0.30825     0.115141
# std     416.974314         1.044151     0.46198     0.319336
# min     128.887118         2.000000     0.00000     0.000000
# 25%     309.797764         2.000000     0.00000     0.000000
# 50%     430.248635         2.000000     0.00000     0.000000
# 75%     657.324303         4.000000     1.00000     0.000000
# max    7782.907225         6.000000     1.00000     1.000000
#
#        cleanliness_rating  guest_satisfaction_overall     bedrooms  \
# count         1103.000000                 1103.000000  1103.000000
# mean             9.461469                   94.362647     1.282865
# std              0.798201                    6.089691     0.740178
# min              4.000000                   20.000000     0.000000
# 25%              9.000000                   92.000000     1.000000
# ...

# %%
print(f"Total null values in the Dataframe - amsterdam_weekdays.csv: {df_AMS_weekdays_drop1.isnull().sum().sum()}")
# Out:
# Total null values in the Dataframe - amsterdam_weekdays.csv: 0

# %%
#print(f"Total duplicated values in the Dataframe - df_ABN: {df_AMS_weekdays['realSum'].duplicated().sum().sum()}")

# %%
df_AMS_weekdays_drop1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1103 entries, 0 to 1102
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   realSum                     1103 non-null   float64
#  1   room_type                   1103 non-null   object
#  2   room_shared                 1103 non-null   bool
#  3   room_private                1103 non-null   bool
#  4   person_capacity             1103 non-null   float64
#  5   host_is_superhost           1103 non-null   bool
#  6   multi                       1103 non-null   int64
#  7   biz                         1103 non-null   int64
#  8   cleanliness_rating          1103 non-null   float64
#  9   guest_satisfaction_overall  1103 non-null   float64
#  10  bedrooms                    1103 non-null   int64
#  11  dist                        1103 non-null   float64
#  12  metro_dist                  1103 non-null   float64
# ...

# %%
df_AMS_weekdays_drop1.describe().T
# Out:
#                              count        mean         std         min  \
# realSum                     1103.0  545.020526  416.974314  128.887118
# person_capacity             1103.0    2.792384    1.044151    2.000000
# multi                       1103.0    0.308250    0.461980    0.000000
# biz                         1103.0    0.115141    0.319336    0.000000
# cleanliness_rating          1103.0    9.461469    0.798201    4.000000
# guest_satisfaction_overall  1103.0   94.362647    6.089691   20.000000
# bedrooms                    1103.0    1.282865    0.740178    0.000000
# dist                        1103.0    2.841621    2.123245    0.015059
# metro_dist                  1103.0    1.089439    0.836546    0.036530
# attr_index                  1103.0  271.009899  197.046890   40.931415
# attr_index_norm             1103.0   14.350154   10.433764    2.167346
# rest_index                  1103.0  341.541187  236.611077   50.877318
# ...

# %%
sns.histplot(
    data=df_AMS_weekdays_drop1,
    x="realSum",
    kde=True,
    bins=40
)

plt.title("Distribution of realSum")
plt.show()

# %%
sns.boxplot(
    data=df_AMS_weekdays_drop1,
    x="realSum"
)

plt.title("Boxplot of realSum")
plt.show()

# %%
df_AMS_weekdays_drop1["log_realSum"] = np.log1p(df_AMS_weekdays_drop1["realSum"])

sns.histplot(
    data=df_AMS_weekdays_drop1,
    x="log_realSum",
    kde=True,
    bins=40
)

plt.title("Distribution of log(realSum)")
plt.show()

# %%
continuous_cols = [
    "dist",
    "metro_dist",
    "attr_index",
    "rest_index",
    "cleanliness_rating",
    "guest_satisfaction_overall"
]

# %%
for col in continuous_cols:
    plt.figure(figsize=(7, 4))

    sns.histplot(
        data=df_AMS_weekdays_drop1,
        x=col,
        kde=True,
        bins=30
    )

    plt.title(f"Distribution of {col}")
    plt.show()

# %%
sns.histplot(
    data=df_AMS_weekdays_drop1,
    x="guest_satisfaction_overall",
    bins=20
)

plt.show()

# %%
discrete_cols = [
    "person_capacity",
    "bedrooms"
]

# %%
sns.countplot(
    data=df_AMS_weekdays_drop1,
    x="person_capacity"
)

plt.title("Person capacity")
plt.show()

# %%
sns.countplot(
    data=df_AMS_weekdays_drop1,
    x="bedrooms"
)

plt.title("Number of bedrooms")
plt.show()

# %%
sns.countplot(
    data=df_AMS_weekdays_drop1,
    x="room_type"
)

plt.title("Room type frequencies")
plt.show()

# %%
sns.boxplot(
    data=df_AMS_weekdays_drop1,
    x="room_type",
    y="realSum"
)

plt.title("Price by room type")
plt.show()

# %%
sns.boxplot(
    data=df_AMS_weekdays_drop1,
    x="room_type",
    y="log_realSum"
)

plt.title("Log price by room type")
plt.show()

# %%
sns.boxplot(
    data=df_AMS_weekdays_drop1,
    x="host_is_superhost",
    y="log_realSum"
)

plt.title("Price by superhost status")
plt.show()

# %%
sns.violinplot(
    data=df_AMS_weekdays_drop1,
    x="host_is_superhost",
    y="log_realSum"
)

plt.show()

# %%
sns.scatterplot(
    data=df_AMS_weekdays_drop1,
    x="dist",
    y="realSum"
)

plt.title("Price vs distance")
plt.show()

# %%
sns.scatterplot(
    data=df_AMS_weekdays_drop1,
    x="dist",
    y="log_realSum"
)

plt.title("Log price vs distance")
plt.show()

# %%
sns.regplot(
    data=df_AMS_weekdays_drop1,
    x="dist",
    y="log_realSum",
    scatter_kws={"alpha": 0.3}
)

plt.show()

# %%
#If the scatter plot is approximately linear:

df_AMS_weekdays_drop1[["realSum", "dist"]].corr(method="pearson")
# Out:
#           realSum      dist
# realSum  1.000000 -0.258692
# dist    -0.258692  1.000000

# %%
#If it is monotonic but nonlinear or contains influential outliers:

df_AMS_weekdays_drop1[["realSum", "dist"]].corr(method="spearman")
# Out:
#           realSum      dist
# realSum  1.000000 -0.389795
# dist    -0.389795  1.000000

# %%
sns.regplot(
    data=df_AMS_weekdays_drop1,
    x="metro_dist",
    y="log_realSum",
    scatter_kws={"alpha": 0.3}
)

plt.title("Log price vs metro distance")
plt.show()

# %%
numeric_cols = [
    "realSum",
    "person_capacity",
    "cleanliness_rating",
    "guest_satisfaction_overall",
    "bedrooms",
    "dist",
    "metro_dist",
    "attr_index",
    "rest_index"
]

corr = df_AMS_weekdays_drop1[numeric_cols].corr()

plt.figure(figsize=(10, 8))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    center=0
)

plt.title("Correlation matrix")
plt.show()

# %%
selected = [
    "log_realSum",
    "person_capacity",
    "bedrooms",
    "dist",
    "metro_dist",
    "guest_satisfaction_overall"
]

sns.pairplot(
    df_AMS_weekdays_drop1[selected],
    corner=True
)

plt.show()

# %%
sns.histplot(
    data=df_AMS_weekdays_drop1,
    x="log_realSum",
    hue="room_type",
    kde=True,
    element="step",
    stat="density",
    common_norm=False
)

plt.title("Price distribution by room type")
plt.show()

# %%
sns.boxplot(
    data=df_AMS_weekdays_drop1,
    x="person_capacity",
    y="log_realSum"
)

plt.show()

# %%
variables = [
    "person_capacity",
    "bedrooms",
    "dist",
    "metro_dist",
    "attr_index",
    "rest_index"
]

for col in variables:

    sns.regplot(
        data=df_AMS_weekdays_drop1,
        x=col,
        y="log_realSum",
        scatter_kws={"alpha": 0.25},
        line_kws={"linewidth": 2}
    )

    plt.title(f"log(realSum) vs {col}")
    plt.show()

# %% [markdown]
# ## Variance is increasing with capacity.
#
# That indicates heteroskedasticity.

# %%
import statsmodels.formula.api as smf

model = smf.ols(
    """
    log_realSum ~
    person_capacity +
    bedrooms +
    dist +
    metro_dist +
    attr_index_norm +
    rest_index_norm +
    guest_satisfaction_overall +
    host_is_superhost +
    C(room_type)
    """,
    data=df_AMS_weekdays_drop1
).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            log_realSum   R-squared:                       0.690
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     243.6
# Date:                Thu, 03 Sep 2026   Prob (F-statistic):          7.31e-270
# Time:                        15:15:44   Log-Likelihood:                -232.76
# No. Observations:                1103   AIC:                             487.5
# Df Residuals:                    1092   BIC:                             542.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        5.1438      0.160     32.147      0.000       4.830       5.458
# ...
